# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 5, 100)
v0 = 10 #anfangsgeschwidnigkeit
angle = 45 #winkel in grad
g = 9.81

angle_rad = np.radians(angle) #umwandlung
x = v0 * np.cos(angle_rad) * t
y = v0 * np.sin(angle_rad) * t - 0.5 * g * t**2

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Wurfbewegung")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 5, 100)
v0 = 5 #anfangsgeschwidnigkeit
angle = 60 #winkel in grad
g = 9.81

angle_rad = np.radians(angle) #umwandlung
x = v0 * np.cos(angle_rad) * t
y = v0 * np.sin(angle_rad) * t - 0.5 * g * t**2

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Wurfbewegung")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 5, 100)
v0 = 50 #anfangsgeschwidnigkeit
angle = 60 #winkel in grad
g = 9.81

angle_rad = np.radians(angle) #umwandlung
x = v0 * np.cos(angle_rad) * t
y = v0 * np.sin(angle_rad) * t - 0.5 * g * t**2

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Wurfbewegung")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 5, 100)
v0 = 50 #anfangsgeschwindigkeit
angle = 20 #winkel in grad
g = 9.81

angle_rad = np.radians(angle) #umwandlung
x = v0 * np.cos(angle_rad) * t
y = v0 * np.sin(angle_rad) * t - 0.5 * g * t**2

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Wurfbewegung")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 5, 100)
v0 = 50 #anfangsgeschwindigkeit
angle = 20 #winkel in grad
g = 9.81

angle_rad = np.radians(angle) #umwandlung
x = v0 * np.cos(angle_rad) * t
y = v0 * np.sin(angle_rad) * t - 0.5 * g * t**2

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Wurfbewegung")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 2.5
angle_2 = 55

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2


plt.plot(x1, y1)
plt.plot(x2, y2)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Zwei Objekte Wurfbewegung")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2


plt.plot(x1, y1, label="A")
plt.plot(x2, y2, label="B")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Zwei Objekte Wurfbewegung")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 2

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level, len(y2))



plt.plot(x1, y1, label="A")
plt.plot(x2, y2, label="B")
plt.scatter(x1_noisy, y1_noisy, label="A+")
plt.scatter(x2_noisy, y2_noisy, label="B+")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Zwei Objekte Wurfbewegung mit Rauschen")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 2

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level, len(y2))



plt.plot(x1, y1, label="A", color='red')
plt.plot(x2, y2, label="B", color='green')
plt.scatter(x1_noisy, y1_noisy, label="A+")
plt.scatter(x2_noisy, y2_noisy, label="B+")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Zwei Objekte Wurfbewegung mit Rauschen")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 5

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level, len(y2))



plt.plot(x1, y1, label="A", color='red')
plt.plot(x2, y2, label="B", color='green')
plt.scatter(x1_noisy, y1_noisy, label="A+")
plt.scatter(x2_noisy, y2_noisy, label="B+")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Zwei Objekte Wurfbewegung mit Rauschen")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 2
noise_level_y = 5

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_y, len(y2))



plt.plot(x1, y1, label="A", color='red')
plt.plot(x2, y2, label="B", color='green')
plt.scatter(x1_noisy, y1_noisy, label="A+")
plt.scatter(x2_noisy, y2_noisy, label="B+")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Zwei Objekte Wurfbewegung mit Rauschen")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 5
noise_level_y = 2

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_y, len(y2))



plt.plot(x1, y1, label="A", color='red')
plt.plot(x2, y2, label="B", color='green')
plt.scatter(x1_noisy, y1_noisy, label="A+")
plt.scatter(x2_noisy, y2_noisy, label="B+")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Zwei Objekte Wurfbewegung mit Rauschen")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 10
noise_level_y = 3

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_y, len(y2))



plt.plot(x1, y1, label="A", color='red')
plt.plot(x2, y2, label="B", color='green')
plt.scatter(x1_noisy, y1_noisy, label="A+")
plt.scatter(x2_noisy, y2_noisy, label="B+")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Zwei Objekte Wurfbewegung mit Rauschen")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 10
noise_level_y = 3
noise_level_2 = 2

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))



plt.plot(x1, y1, label="A", color='red')
plt.plot(x2, y2, label="B", color='green')
plt.scatter(x1_noisy, y1_noisy, label="A+")
plt.scatter(x2_noisy, y2_noisy, label="B+")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Zwei Objekte Wurfbewegung mit unterschiedlichem Rauschen")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))

#zuordnen lernen, punkte mischen
points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])

#reihenfolge zufällig machen
indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]

plt.scatter(points_x, points_y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Gemischte Messpunkte")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))

#zuordnen lernen, punkte mischen
points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])

#reihenfolge zufällig machen
indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]

#daten trennen
mask1 = points_x < 70
mask2 = points_x >= 70

x_group1 = points_x[mask1]
x_group2 = points_x[mask2]

y_group1 = points_y[mask1]
y_group2 = points_y[mask2]

#angepasste parabel
coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)

x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly1(x_fit2)

plt.scatter(points_x, points_y)
plt.plot(x_fit1, y_fit1, label='Fit 1')
plt.plot(x_fit2, y_fit2, label='Fit 2')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Gemischte Messpunkte mit Parabelfit")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))

#zuordnen lernen, punkte mischen
points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])

#reihenfolge zufällig machen
indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]

#daten clustern automatisch ordnenn lassen
points = np.column_stack((points_x, points_y))

#gruppen größe beim ordnen
kmeans = KMeans(n_clusters=2)
labels = kmeans.fit_predict(points)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]

plt.scatter(points_x, points_y)
plt.scatter(x_group1, y_group1, label='Gruppe 1')
plt.scatter(x_group2, y_group2, label='Gruppe 2')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Gemischte Messpunkte mit Ordnung in zwei Gruppen")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))

#zuordnen lernen, punkte mischen
points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])

#reihenfolge zufällig machen
indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]

#daten clustern automatisch ordnenn lassen, geiwchtung auf die x achse legen
points = np.column_stack((points_x * 10, points_y))

#gruppen größe beim ordnen
kmeans = KMeans(n_clusters=2)
labels = kmeans.fit_predict(points)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]

plt.scatter(points_x, points_y)
plt.scatter(x_group1, y_group1, label='Gruppe 1')
plt.scatter(x_group2, y_group2, label='Gruppe 2')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Gemischte Messpunkte mit Ordnung in zwei Gruppen")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))

#zuordnen lernen, punkte mischen
points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])

#reihenfolge zufällig machen
indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]

#daten clustern nach x
points_for_kmeans = points_x.reshape(-1, 1)

#gruppen größe beim ordnen
kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]

plt.scatter(points_x, points_y)
plt.scatter(x_group1, y_group1, label='Gruppe 1')
plt.scatter(x_group2, y_group2, label='Gruppe 2')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ordnung der Messwerte nach x")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))

#zuordnen lernen, punkte mischen
points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])

#reihenfolge zufällig machen
indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]

#daten clustern nach x
points_for_kmeans = points_x.reshape(-1, 1)

#gruppen größe beim ordnen
kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]

#angepasste parabel
coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)

#abstand zur parabel bestimmen
d1 = np.abs(points_y - poly1(points_x))
d2 = np.abs(points_y - poly2(points_x))

#nach abstand zu ordnen
mask1 = d1 < d2
mask2 = ~mask1

x_group1_new = points_x[mask1]
y_group1_new = points_y[mask1]

x_group2_new = points_x[mask2]
y_group2_new = points_y[mask2]

#neuer parabel fit
coef1_new = np.polyfit(x_group1_new, y_group1_new, 2)
coef2_new = np.polyfit(x_group2_new, y_group2_new, 2)

poly1_new = np.poly1d(coef1_new)
poly2_new = np.poly1d(coef2_new)

#zeichnen
x_fit1 = np.linspace(min(x_group1_new), max(x_group1_new), 200)
x_fit2 = np.linspace(min(x_group2_new), max(x_group2_new), 200)

y_fit1 = poly1_new(x_fit1)
y_fit2 = poly2_new(x_fit2)

plt.scatter(x_group1_new, y_group1_new, label='Gruppe 1')
plt.scatter(x_group2_new, y_group2_new, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Ordnung nach x")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))

#zuordnen lernen, punkte mischen
points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])

#reihenfolge zufällig machen
indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]

#daten clustern nach x
points_for_kmeans = points_x.reshape(-1, 1)

#gruppen größe beim ordnen
kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]

#angepasste parabel
coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)

#abstand zur parabel bestimmen
d1 = np.abs(points_y - poly1(points_x))
d2 = np.abs(points_y - poly2(points_x))

#nach abstand zu ordnen
mask1 = d1 < d2
mask2 = ~mask1

x_group1_new = points_x[mask1]
y_group1_new = points_y[mask1]

x_group2_new = points_x[mask2]
y_group2_new = points_y[mask2]

#neuer parabel fit
coef1_new = np.polyfit(x_group1_new, y_group1_new, 2)
coef2_new = np.polyfit(x_group2_new, y_group2_new, 2)

poly1_new = np.poly1d(coef1_new)
poly2_new = np.poly1d(coef2_new)

#zeichnen
x_fit1 = np.linspace(min(x_group1_new), max(x_group1_new), 200)
x_fit2 = np.linspace(min(x_group2_new), max(x_group2_new), 200)

y_fit1 = poly1_new(x_fit1)
y_fit2 = poly2_new(x_fit2)

plt.scatter(x_group1_new, y_group1_new, s=10, label='Gruppe 1')
plt.scatter(x_group2_new, y_group2_new, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Ordnung nach x")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))


points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])


indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]


points_for_kmeans = points_x.reshape(-1, 1)


kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

for _ in range(10):
    x_group1 = points_x[labels == 0]
    y_group1 = points_y[labels == 0]

    x_group2 = points_x[labels == 1]
    y_group2 = points_y[labels == 1]


    coef1 = np.polyfit(x_group1, y_group1, 2)
    coef2 = np.polyfit(x_group2, y_group2, 2)

    poly1 = np.poly1d(coef1)
    poly2 = np.poly1d(coef2)


    d1 = np.abs(points_y - poly1(points_x))
    d2 = np.abs(points_y - poly2(points_x))

    labels = (d2 < d1).astype(int)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]


coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)


x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly2(x_fit2)

plt.scatter(x_group1, y_group1, s=10, label='Gruppe 1')
plt.scatter(x_group2, y_group2, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Abstand zur Parabel")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))


points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])


indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]


points_for_kmeans = points_x.reshape(-1, 1)


kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

for _ in range(20):
    x_group1 = points_x[labels == 0]
    y_group1 = points_y[labels == 0]

    x_group2 = points_x[labels == 1]
    y_group2 = points_y[labels == 1]


    coef1 = np.polyfit(x_group1, y_group1, 2)
    coef2 = np.polyfit(x_group2, y_group2, 2)

    poly1 = np.poly1d(coef1)
    poly2 = np.poly1d(coef2)


    d1 = np.abs(points_y - poly1(points_x))
    d2 = np.abs(points_y - poly2(points_x))

    labels = (d2 < d1).astype(int)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]


coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)


x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly2(x_fit2)

plt.scatter(x_group1, y_group1, s=10, label='Gruppe 1')
plt.scatter(x_group2, y_group2, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Abstand zur Parabel")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

#objekt 2
v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

#mit rauschen
noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))


points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])


indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]


points_for_kmeans = points_x.reshape(-1, 1)


kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

for _ in range(100):
    x_group1 = points_x[labels == 0]
    y_group1 = points_y[labels == 0]

    x_group2 = points_x[labels == 1]
    y_group2 = points_y[labels == 1]


    coef1 = np.polyfit(x_group1, y_group1, 2)
    coef2 = np.polyfit(x_group2, y_group2, 2)

    poly1 = np.poly1d(coef1)
    poly2 = np.poly1d(coef2)


    d1 = np.abs(points_y - poly1(points_x))
    d2 = np.abs(points_y - poly2(points_x))

    labels = (d2 < d1).astype(int)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]


coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)


x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly2(x_fit2)

plt.scatter(x_group1, y_group1, s=10, label='Gruppe 1')
plt.scatter(x_group2, y_group2, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Abstand zur Parabel")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

#objekt 1
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = v0_1 * np.sin(a1) * t - 0.5 * g * t**2

v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = v0_2 * np.sin(a2) * t - 0.5 * g * t**2

mask1 = y1 >= 0
x1 = x1[mask1]
y1 = y1[mask1]

mask2 = y2 >= 0
x2 = x2[mask2]
y2 = y2[mask2]

noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))


points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])


indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]


points_for_kmeans = points_x.reshape(-1, 1)


kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

for _ in range(10):
    x_group1 = points_x[labels == 0]
    y_group1 = points_y[labels == 0]

    x_group2 = points_x[labels == 1]
    y_group2 = points_y[labels == 1]


    coef1 = np.polyfit(x_group1, y_group1, 2)
    coef2 = np.polyfit(x_group2, y_group2, 2)

    poly1 = np.poly1d(coef1)
    poly2 = np.poly1d(coef2)


    d1 = np.abs(points_y - poly1(points_x))
    d2 = np.abs(points_y - poly2(points_x))

    labels = (d2 < d1).astype(int)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]


coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)


x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly2(x_fit2)

plt.scatter(x_group1, y_group1, s=10, label='Gruppe 1')
plt.scatter(x_group2, y_group2, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Abstand zur Parabel")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

y0_1 = 50
y0_2 = 35
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = y0_1 + v0_1 * np.sin(a1) * t - 0.5 * g * t**2


v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = y0_2 + v0_2 * np.sin(a2) * t - 0.5 * g * t**2

mask1 = y1 >= 0
x1 = x1[mask1]
y1 = y1[mask1]

mask2 = y2 >= 0
x2 = x2[mask2]
y2 = y2[mask2]

noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))


points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])


indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]


points_for_kmeans = points_x.reshape(-1, 1)


kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

for _ in range(10):
    x_group1 = points_x[labels == 0]
    y_group1 = points_y[labels == 0]

    x_group2 = points_x[labels == 1]
    y_group2 = points_y[labels == 1]


    coef1 = np.polyfit(x_group1, y_group1, 2)
    coef2 = np.polyfit(x_group2, y_group2, 2)

    poly1 = np.poly1d(coef1)
    poly2 = np.poly1d(coef2)


    d1 = np.abs(points_y - poly1(points_x))
    d2 = np.abs(points_y - poly2(points_x))

    labels = (d2 < d1).astype(int)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]


coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)


x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly2(x_fit2)

plt.scatter(x_group1, y_group1, s=10, label='Gruppe 1')
plt.scatter(x_group2, y_group2, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Abstand zur Parabel")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

y0_1 = 80
y0_2 = 35
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = y0_1 + v0_1 * np.sin(a1) * t - 0.5 * g * t**2


v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = y0_2 + v0_2 * np.sin(a2) * t - 0.5 * g * t**2

mask1 = y1 >= 0
x1 = x1[mask1]
y1 = y1[mask1]

mask2 = y2 >= 0
x2 = x2[mask2]
y2 = y2[mask2]

noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))


points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])


indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]


points_for_kmeans = points_x.reshape(-1, 1)


kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

for _ in range(10):
    x_group1 = points_x[labels == 0]
    y_group1 = points_y[labels == 0]

    x_group2 = points_x[labels == 1]
    y_group2 = points_y[labels == 1]


    coef1 = np.polyfit(x_group1, y_group1, 2)
    coef2 = np.polyfit(x_group2, y_group2, 2)

    poly1 = np.poly1d(coef1)
    poly2 = np.poly1d(coef2)


    d1 = np.abs(points_y - poly1(points_x))
    d2 = np.abs(points_y - poly2(points_x))

    labels = (d2 < d1).astype(int)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]


coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)


x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly2(x_fit2)

plt.scatter(x_group1, y_group1, s=10, label='Gruppe 1')
plt.scatter(x_group2, y_group2, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Abstand zur Parabel")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

y0_1 = 80
y0_2 = 35
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = y0_1 + v0_1 * np.sin(a1) * t - 0.5 * g * t**2


v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = y0_2 + v0_2 * np.sin(a2) * t - 0.5 * g * t**2

mask1 = y1 >= 0
x1 = x1[mask1]
y1 = y1[mask1]

mask2 = y2 >= 0
x2 = x2[mask2]
y2 = y2[mask2]

noise_level = 7
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))


points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])


indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]


points_for_kmeans = points_x.reshape(-1, 1)


kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

for _ in range(100):
    x_group1 = points_x[labels == 0]
    y_group1 = points_y[labels == 0]

    x_group2 = points_x[labels == 1]
    y_group2 = points_y[labels == 1]


    coef1 = np.polyfit(x_group1, y_group1, 2)
    coef2 = np.polyfit(x_group2, y_group2, 2)

    poly1 = np.poly1d(coef1)
    poly2 = np.poly1d(coef2)


    d1 = np.abs(points_y - poly1(points_x))
    d2 = np.abs(points_y - poly2(points_x))

    labels = (d2 < d1).astype(int)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]


coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)


x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly2(x_fit2)

plt.scatter(x_group1, y_group1, s=10, label='Gruppe 1')
plt.scatter(x_group2, y_group2, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Abstand zur Parabel")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

y0_1 = 80
y0_2 = 35
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = y0_1 + v0_1 * np.sin(a1) * t - 0.5 * g * t**2


v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = y0_2 + v0_2 * np.sin(a2) * t - 0.5 * g * t**2

mask1 = y1 >= 0
x1 = x1[mask1]
y1 = y1[mask1]

mask2 = y2 >= 0
x2 = x2[mask2]
y2 = y2[mask2]

noise_level = 2
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))


points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])


indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]


points_for_kmeans = points_x.reshape(-1, 1)


kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

for _ in range(100):
    x_group1 = points_x[labels == 0]
    y_group1 = points_y[labels == 0]

    x_group2 = points_x[labels == 1]
    y_group2 = points_y[labels == 1]


    coef1 = np.polyfit(x_group1, y_group1, 2)
    coef2 = np.polyfit(x_group2, y_group2, 2)

    poly1 = np.poly1d(coef1)
    poly2 = np.poly1d(coef2)


    d1 = np.abs(points_y - poly1(points_x))
    d2 = np.abs(points_y - poly2(points_x))

    labels = (d2 < d1).astype(int)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]


coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)


x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly2(x_fit2)

plt.scatter(x_group1, y_group1, s=10, label='Gruppe 1')
plt.scatter(x_group2, y_group2, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Abstand zur Parabel")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

t = np.linspace(0, 20, 400)
g = 9.81

y0_1 = 80
y0_2 = 35
v0_1 = 5
angle_1 = 60

a1 = np.radians(angle_1)
x1 = v0_1 * np.cos(a1) * t
y1 = y0_1 + v0_1 * np.sin(a1) * t - 0.5 * g * t**2


v0_2 = 10
angle_2 = 35

a2 = np.radians(angle_2)
x2 = v0_2 * np.cos(a2) * t
y2 = y0_2 + v0_2 * np.sin(a2) * t - 0.5 * g * t**2

mask1 = y1 >= 0
x1 = x1[mask1]
y1 = y1[mask1]

mask2 = y2 >= 0
x2 = x2[mask2]
y2 = y2[mask2]

noise_level = 2
noise_level_y = 3
noise_level_2 = 4

x1_noisy = x1 + np.random.normal(0, noise_level, len(x1))
y1_noisy = y1 + np.random.normal(0, noise_level_y, len(y1))

x2_noisy = x2 + np.random.normal(0, noise_level_2, len(x2))
y2_noisy = y2 + np.random.normal(0, noise_level_2, len(y2))


points_x = np.concatenate([x1_noisy, x2_noisy])
points_y = np.concatenate([y1_noisy, y2_noisy])


indices = np.random.permutation(len(points_x))

points_x = points_x[indices]
points_y = points_y[indices]


points_for_kmeans = points_x.reshape(-1, 1)


kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(points_for_kmeans)

for _ in range(15):
    x_group1 = points_x[labels == 0]
    y_group1 = points_y[labels == 0]

    x_group2 = points_x[labels == 1]
    y_group2 = points_y[labels == 1]


    coef1 = np.polyfit(x_group1, y_group1, 2)
    coef2 = np.polyfit(x_group2, y_group2, 2)

    poly1 = np.poly1d(coef1)
    poly2 = np.poly1d(coef2)


    d1 = np.abs(points_y - poly1(points_x))
    d2 = np.abs(points_y - poly2(points_x))

    labels = (d2 < d1).astype(int)

x_group1 = points_x[labels == 0]
y_group1 = points_y[labels == 0]

x_group2 = points_x[labels == 1]
y_group2 = points_y[labels == 1]


coef1 = np.polyfit(x_group1, y_group1, 2)
coef2 = np.polyfit(x_group2, y_group2, 2)

poly1 = np.poly1d(coef1)
poly2 = np.poly1d(coef2)


x_fit1 = np.linspace(min(x_group1), max(x_group1), 200)
x_fit2 = np.linspace(min(x_group2), max(x_group2), 200)

y_fit1 = poly1(x_fit1)
y_fit2 = poly2(x_fit2)

plt.scatter(x_group1, y_group1, s=10, label='Gruppe 1')
plt.scatter(x_group2, y_group2, s=10, label='Gruppe 2')
plt.plot(x_fit1, y_fit1, label='Fit 1', color='red')
plt.plot(x_fit2, y_fit2, label='Fit 2', color='green')

plt.xlabel("x")
plt.ylabel("y")
plt.title("Parabelfit nach Abstand zur Parabel")
plt.legend()
plt.show()
